# %% [markdown]
# <a href="https://colab.research.google.com/github/subodhbhartismiley/Object-Detection-Person-and-Vehicle/blob/main/Collect_data%2C_Renaming_Image_seq_done%2C_Annotaion_technique%2C_testing_of_yolov5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Collect data (images) Auto as web scraping

# %%
pip install bing_image_downloader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !mkdir images_test2

# %%
from bing_image_downloader import downloader
query_string = 'Man and vehicle'
#downloader.download(query_string, limit=100, output_dir='dataset1', adult_filter_off=True )
downloader.download(query_string, limit=800, output_dir='images_test1')

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# 'D:\\New_dir'

# %%
# change directory
os.chdir('D:\\New_dir')

# %%
print(os.getcwd())
# Out:
# D:\New_dir

# %%
# Renaming files as sequential order image0 to image799 after manual copy all folder files in one folder
import os
 
#os.chdir('D:\\Geeksforgeeks')
print(os.getcwd())
folder = "New folder_800"
for count, filename in enumerate(os.listdir(folder)):
    f_name, f_ext = os.path.splitext(filename)
    src =f"{folder}/{filename}"
    dst = f"image {str(count)}{f_ext}"
    dst =f"{folder}/{dst}"
 
    #new_name = f'{f_name}{f_ext}'   # as dst
    #os.rename(f, new_name)
    os.rename(src, dst)
# Out:
# D:\New_dir

# %%
# change directory
os.chdir('D:\\New_dir')

# %%
current_folder = os.getcwd()

# %%
current_folder
# Out:
# 'D:\\New_dir'

# %%
#try:
# !mkdir New_dir\destination_dir

# %%
# if folder not available then make the folder
path="D:\\New_dir\\destination_dir1"
if os.path.exists(path)==False:
    try:
        # !mkdir destination_dir1
    except Error as e:
        pass

# %%
current_folder = os.getcwd()

# %% [markdown]
# ### Renaming Image files of Man and Vehicle as sequential order image1 to image800 after manual copy all files of all folder in one folder

# %%
os.getcwd()
# Out:
# 'D:\\New_dir'

# %%
# Renaming files as sequential order image1 to image800 after manual copy all folder files in one folder
import os
import subprocess
#import shutil

os.chdir('D:\\New_dir')   #D:\New_dir\Image data man and vehicle\Auto and manual images merged_Copy
                            # Always to keep sorce folder in main folder of directory like C or D 
print(os.getcwd())
folder = "Auto and manual images merged_Copy1"
for count, filename in enumerate(os.listdir(folder)):
    filename, f_ext = os.path.splitext(filename)
    #print(f_ext)
    
    src =f"{folder}/{filename}{f_ext}"
    f_ext='.jpg'
    dst = f"image_{str(count+1)}{f_ext}"
    dst =f"{folder}/{dst}"
    
    try:
        os.rename(src, dst)
    except FileExistsError as e:
        pass

# %% [markdown]
# ### Renaming files as in sequential order image1 to image126 after Manually collected vehicle license plates without separation

# %%
# Renaming files as in sequential order image1 to image126 after Manually collected vehicle license plates
import subprocess
#import shutil

os.chdir('D:\\New_dir')   #D:\New_dir\Image data man and vehicle\Auto and manual images merged_Copy
                            # Always to keep sorce folder in main folder of directory like C or D 
print(os.getcwd())
folder = "Manually collected vehicle license plates"
for count, filename in enumerate(os.listdir(folder)):
    filename, f_ext = os.path.splitext(filename)
    #print(f_ext)
    
    src =f"{folder}/{filename}{f_ext}"
    f_ext='.jpg'
    dst = f"image_{str(count+1)}{f_ext}"
    dst =f"{folder}/{dst}"
    
    try:
        os.rename(src, dst)
    except FileExistsError as e:
        pass
# Out:
# D:\New_dir

# %%
pip install pyqt5 lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install labelImg
# Out:
# ...
#      -------------------------------------- 247.7/247.7 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for labelImg: filename=labelImg-1.8.6-py2.py3-none-any.whl size=261544 sha256=0fb70d025e9b66108a33dd78251a2327260bfed39c83cbd35468f2e4452b02e5
#   Stored in directory: c:\users\sub13\appdata\local\pip\cache\wheels\df\39\12\bf80c441ad46616d5b271867a6ece21e8a083af10903b8e53a
# Successfully built labelImg
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# * run labelImg in Anaconda cmd after installation for manual annotations

# %%
'''
use for manual annotations
Make Sense AI
https://www.makesense.ai
browser based
'''

# %% [markdown]
# ### Use yolov5 for Auto Annotaion for predefined classes
# * Whereas my class vehicle was alone not defined.

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()
# Out:
# C:\Users\sub13\anaconda3\lib\site-packages\torch\hub.py:266: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\sub13/.cache\torch\hub\master.zip
# YOLOv5  2022-10-20 Python-3.9.12 torch-1.12.1+cpu CPU
# [Errno 2] No such file or directory: 'c:\\users\\sub13\\anaconda3\\lib\\site-packages\\ipython-8.2.0.dist-info\\METADATA'
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# ...

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x1C3F71FA6D0>
# <PIL.Image.Image image mode=RGB size=810x1080 at 0x1C3F71FA700>
